# %%
import sys
sys.path.append("/home/luiz/Work/ING/experimentation-day/ai-attack/Attacks using macros/python_code/vba2graph/")

from vba2graph import *

def extract_features(input_file_name="path_to_file", macro_file=False, output_folder="output"):

    # ****************************************************************************
    # *                              Argument Parser                             *
    # ****************************************************************************

    input_vba_content = ""

    # handle files
    if os.path.isfile(input_file_name):
        if macro_file is False:
            input_vba_content = handle_input(input_file_name, is_piped=False)
        else:
            input_vba_content = vba2graph_from_vba_object(input_file_name)

    # handle wrong input
    else:
        logger.error("Invalid input path")
        sys.exit(1)

    input_file_name = os.path.basename(input_file_name)
    
    return vba2graph_gen(input_vba_content, output_folder, input_file_name, color_scheme)

def vba2graph_gen(input_vba_content, output_folder="output", input_file_name="vba2graph", color_scheme=color_scheme):

    """ Generage graph from processed vba macros
    Args:
        input_vba_content (string): data generated by handle_olevba_input
        output_folder (string): output folder
        input_file_name (string): base filename
        color_scheme (int): color scheme number [0, 1, 2, 3] (default: 0 - B&W)
    """

    # ****************************************************************************
    # *                               Process Input                              *
    # ****************************************************************************

    vba_content_lines = vba_seperate_lines(input_vba_content)
    vba_content_lines_no_whitespace = vba_clean_whitespace(vba_content_lines)
    vba_content_lines_no_metadata = vba_clean_metadata(
        vba_content_lines_no_whitespace)
    vba_content_deobfuscated = vba_deobfuscation(vba_content_lines_no_metadata)
    vba_func_dict = vba_extract_functions(vba_content_deobfuscated)
    vba_prop_dict = vba_extract_properties(vba_content_lines_no_metadata)

    # treat properties like functions and merge both dictionaries
    vba_func_dict = dict(vba_func_dict.items() + vba_prop_dict.items())

    ##############################################################################
    # at this point, vba_func_dict should contain the code of functions and
    # properties, without comments or whitespaces.
    ##############################################################################

    # ****************************************************************************
    # *                              Generate Graph                              *
    # ****************************************************************************

    DG = create_call_graph(vba_func_dict)
    DG = find_keywords_in_graph(vba_func_dict, DG)
    DG = find_change_flow(vba_func_dict, DG)
    return DG

# %%
def find_keywords_in_graph(vba_func_dict, DG):
    """Find and highlight possible malicious keywords in graph
    
    Args:
        vba_func_dict (dict[func_name]=func_code): Functions dictionary
        DG (networkx.DiGraph): Generated directed graph
    
    Returns:
        networkx.DiGraph: Directed Graph with keywords highlighted in red
    """
    # analyze function calls
    for func_name in vba_func_dict:

        func_code = vba_func_dict[func_name]
        # split function code into lines
        func_code_lines = filter(None, re.split("\n", func_code))

        # handle malicious keywords
        keywords_re_sensetive = "(" + ")|(".join(lst_mal_case_sensetive) + ")"
        keywords_re_insensetive = "(" + ")|(".join(lst_mal_case_insensetive) + ")"

        # iterate over all the words in func_code and match mal_regexes
        dict_items = {}
        for token in func_code_lines:
            match_findall_sensetive = re.findall(keywords_re_sensetive, token)
            match_findall_insensetive = re.findall(keywords_re_insensetive, token, re.IGNORECASE)
            match_findall = match_findall_sensetive + match_findall_insensetive
            if match_findall:
                for match in match_findall:
                    match_list = list(match)

                    # use dictionary dict_items to count occurances of keywords
                    for list_item in match_list:
                        if list_item != "":
                            if list_item not in dict_items:
                                dict_items[list_item] = 1
                            else:
                                dict_items[list_item] = dict_items[list_item] + 1

        # add keywords to graph
        for dic_key in dict_items:
            if dic_key in lst_obfuscation_keywords:
                keyword_color = color_scheme["COLOR_OBFUSCATION_KEYWORD"]
                sensitivity = "OBFUSCATED"
            else:
                keyword_color = color_scheme["COLOR_REGULAR_KEYWORD"]
                sensitivity = 'REGULAR'
                

            keyword_count = dict_items[dic_key]
            if DG.node[func_name]["keywords"] != "":
                DG.node[func_name]["keywords"] = DG.node[func_name]["keywords"] + ","

            DG.node[func_name]["keywords"] = DG.node[func_name]["keywords"] + "<font color='" + keyword_color + "'>" + dic_key + "[" + str(keyword_count) + "]" + "</font>"
            
            call = {'name': dic_key, 
                    "count": keyword_count,
                    "sensitivity": sensitivity,}

            if "calls" in DG.node[func_name]:
                DG.node[func_name]["calls"].append(call)
            else:
                DG.node[func_name]["calls"] = [call]

        # handle autorun keywords
        keywords_re = "(" + ")|(".join(lst_autorun) + ")"
        if re.match(keywords_re, func_name, re.IGNORECASE):
            DG.node[func_name]["color"] = color_scheme["COLOR_AUTORUN_FUNCTIONS"]

    return DG

# %%
path = '/home/luiz/Work/ING/experimentation-day/ai-attack/Attacks using macros/data/'
data = []
for label in ('good', 'bad'):
    for f in os.listdir(path + label):
        f_path = os.path.join(path, label, f)
        print f_path
        if ".xls" in f:
            dg = extract_features(f_path, macro_file=False)
        else:
            dg = extract_features(f_path, macro_file=False)


        print dg
        for node in dg.nodes(data=True):
            calls = node[1]['calls']
            for c in calls:
                d = c
                d["function_name"] = node[0]
                d["file_name"] = f
                d["label"] = label
                data.append(d)


data_pd = pd.DataFrame(data)
# Out:
# /home/luiz/Work/ING/experimentation-day/ai-attack/Attacks using macros/data/good/DiversenBerekeningen.xlsm
#
# /home/luiz/Work/ING/experimentation-day/ai-attack/Attacks using macros/data/good/VBAatje.xlsm
#
# /home/luiz/Work/ING/experimentation-day/ai-attack/Attacks using macros/data/good/DiversenGrafieken.xlsm
#
# /home/luiz/Work/ING/experimentation-day/ai-attack/Attacks using macros/data/good/FormulierOpgave.xlsm
#
# /home/luiz/Work/ING/experimentation-day/ai-attack/Attacks using macros/data/good/MSEAnder.xlsm
#
# /home/luiz/Work/ING/experimentation-day/ai-attack/Attacks using macros/data/good/OpmaakOpgave.xlsm
#
# /home/luiz/Work/ING/experimentation-day/ai-attack/Attacks using macros/data/good/Lijsten.xlsm
#
# /home/luiz/Work/ING/experimentation-day/ai-attack/Attacks using macros/data/good/DiversenGrafiekenFunctieAnalyse (1).xlsm
#
# /home/luiz/Work/ING/experimentation-day/ai-attack/Attacks using macros/data/good/QatifAbstract.xlsx
#
# /home/luiz/Work/ING/experimentation-day/ai-attack/Attacks using macros/data/good/DiversenRariteiten(1).xlsm
#
# /home/luiz/Work/ING/experimentation-day/ai-attack/Attacks using macros/data/good/FunctiesAlle2016.xlsm
#
# /home/luiz/Work/ING/experimentation-day/ai-attack/Attacks using macros/data/good/DiversenGrafiekenFunctieAnalyse.xlsm
#
# /home/luiz/Work/ING/experimentation-day/ai-attack/Attacks using macros/data/good/DiversenGrafiekenPeltier.xlsm
#
# /home/luiz/Work/ING/experimentation-day/ai-attack/Attacks using macros/data/good/LijstenOpgave.xlsm
#
# /home/luiz/Work/ING/experimentation-day/ai-attack/Attacks using macros/data/good/DraaitabelOpgave2010.xlsm
#
# /home/luiz/Work/ING/experimentation-day/ai-attack/Attacks using macros/data/good/DraaitabelOpgave2003.xlsm
#
# /home/luiz/Work/ING/experimentation-day/ai-attack/Attacks using macros/data/good/DiversenGrafiekenOmwentelingen (1).xlsm
#
# /home/luiz/Work/ING/experimentation-day/ai-attack/Attacks using macros/data/good/Formules_FunctiesOpgave.xlsm
#
# /home/luiz/Work/ING/experimentation-day/ai-attack/Attacks using macros/data/good/DraaitabelOpgave2010 (1).xlsm
#
# /home/luiz/Work/ING/experimentation-day/ai-attack/Attacks using macros/data/good/FunctiesAlleOpgave2010.xlsm
#
# /home/luiz/Work/ING/experimentation-day/ai-attack/Attacks using macros/data/good/DiversenOplosser.xlsm
#
# /home/luiz/Work/ING/experimentation-day/ai-attack/Attacks using macros/data/good/Formules_FunctiesOpgave(1).xlsm
#
# /home/luiz/Work/ING/experimentation-day/ai-attack/Attacks using macros/data/good/DiversenGrafiekenOmwentelingen.xlsm
#
# /home/luiz/Work/ING/experimentation-day/ai-attack/Attacks using macros/data/good/MSEAnderOpgave.xlsm
#
# /home/luiz/Work/ING/experimentation-day/ai-attack/Attacks using macros/data/good/DiversenRariteiten.xlsm
#
# /home/luiz/Work/ING/experimentation-day/ai-attack/Attacks using macros/data/good/Formules_Functies.xlsm
#
# /home/luiz/Work/ING/experimentation-day/ai-attack/Attacks using macros/data/good/DiversenDatumTijd.xlsm
#
# /home/luiz/Work/ING/experimentation-day/ai-attack/Attacks using macros/data/good/performance test IILD.xlsx
#
# /home/luiz/Work/ING/experimentation-day/ai-attack/Attacks using macros/data/good/DiversenGrafiekenPeltier(1).xlsm
#
# /home/luiz/Work/ING/experimentation-day/ai-attack/Attacks using macros/data/good/Formules_Functies(1).xlsm
#
# /home/luiz/Work/ING/experimentation-day/ai-attack/Attacks using macros/data/good/Copy of Missing_2017_20.xlsb
#
# /home/luiz/Work/ING/experimentation-day/ai-attack/Attacks using macros/data/bad/99eb1d90eb5f0d012f35fcc2a7dedd2229312794354843637ebb7f40b74d0809.macro
#
# /home/luiz/Work/ING/experimentation-day/ai-attack/Attacks using macros/data/bad/645372552748a419b07f90311838bc37ea43c2ef47c9c0c8bc03438020261a36.macro
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-106-86c50ca77a61> in <module>()
#      13         print dg
#      14         for node in dg.nodes(data=True):
# ---> 15             calls = node[1]['calls']
#      16             for c in calls:
#      17                 d = c
#
# KeyError: 'calls'

# %%
dg = extract_features("/home/luiz/Work/ING/experimentation-day/ai-attack/Attacks using macros/data/good/DiversenBerekeningen.xlsm",
                      macro_file=False)
dg.nodes()
# Out:
# NodeView(())

# %%
data_pd
# Out:
#      count                                          file_name  \
# 0       20  99eb1d90eb5f0d012f35fcc2a7dedd2229312794354843...
# 1       16  99eb1d90eb5f0d012f35fcc2a7dedd2229312794354843...
# 2       22  99eb1d90eb5f0d012f35fcc2a7dedd2229312794354843...
# 3       35  99eb1d90eb5f0d012f35fcc2a7dedd2229312794354843...
# 4       35  99eb1d90eb5f0d012f35fcc2a7dedd2229312794354843...
# 5       12  99eb1d90eb5f0d012f35fcc2a7dedd2229312794354843...
# 6       31  99eb1d90eb5f0d012f35fcc2a7dedd2229312794354843...
# 7        1  99eb1d90eb5f0d012f35fcc2a7dedd2229312794354843...
# 8       40  99eb1d90eb5f0d012f35fcc2a7dedd2229312794354843...
# 9       23  99eb1d90eb5f0d012f35fcc2a7dedd2229312794354843...
# 10     114  99eb1d90eb5f0d012f35fcc2a7dedd2229312794354843...
# 11       2  99eb1d90eb5f0d012f35fcc2a7dedd2229312794354843...
# 12       1  99eb1d90eb5f0d012f35fcc2a7dedd2229312794354843...
# 13       8  99eb1d90eb5f0d012f35fcc2a7dedd2229312794354843...
# 14      95  99eb1d90eb5f0d012f35fcc2a7dedd2229312794354843...
# 15      43  99eb1d90eb5f0d012f35fcc2a7dedd2229312794354843...
# 16     113  99eb1d90eb5f0d012f35fcc2a7dedd2229312794354843...
# 17       2  99eb1d90eb5f0d012f35fcc2a7dedd2229312794354843...
# 18     119  99eb1d90eb5f0d012f35fcc2a7dedd2229312794354843...
# 19      20  9c67a05a0e6350069a7e6d201c971dd11c63fdf548a4d3...
# 20      16  9c67a05a0e6350069a7e6d201c971dd11c63fdf548a4d3...
# 21      22  9c67a05a0e6350069a7e6d201c971dd11c63fdf548a4d3...
# 22      35  9c67a05a0e6350069a7e6d201c971dd11c63fdf548a4d3...
# 23      35  9c67a05a0e6350069a7e6d201c971dd11c63fdf548a4d3...
# 24      12  9c67a05a0e6350069a7e6d201c971dd11c63fdf548a4d3...
# 25      31  9c67a05a0e6350069a7e6d201c971dd11c63fdf548a4d3...
# 26       1  9c67a05a0e6350069a7e6d201c971dd11c63fdf548a4d3...
# 27      40  9c67a05a0e6350069a7e6d201c971dd11c63fdf548a4d3...
# 28      23  9c67a05a0e6350069a7e6d201c971dd11c63fdf548a4d3...
# 29     114  9c67a05a0e6350069a7e6d201c971dd11c63fdf548a4d3...
# ..     ...                                                ...
# 100    114                       infected_vba-_evilsnappy.vba
# 101      2                       infected_vba-_evilsnappy.vba
# 102    114                       infected_vba-_evilsnappy.vba
# 103     70  26de80e3bbbe1f053da4131ca7a405644b7443356ec97d...
# 104     10  26de80e3bbbe1f053da4131ca7a405644b7443356ec97d...
# 105     34  26de80e3bbbe1f053da4131ca7a405644b7443356ec97d...
# 106     91  26de80e3bbbe1f053da4131ca7a405644b7443356ec97d...
# 107     91  26de80e3bbbe1f053da4131ca7a405644b7443356ec97d...
# 108     64  26de80e3bbbe1f053da4131ca7a405644b7443356ec97d...
# 109      1  26de80e3bbbe1f053da4131ca7a405644b7443356ec97d...
# 110      6  26de80e3bbbe1f053da4131ca7a405644b7443356ec97d...
# 111     25  26de80e3bbbe1f053da4131ca7a405644b7443356ec97d...
# 112     42  26de80e3bbbe1f053da4131ca7a405644b7443356ec97d...
# 113     64  26de80e3bbbe1f053da4131ca7a405644b7443356ec97d...
# 114      1  26de80e3bbbe1f053da4131ca7a405644b7443356ec97d...
# 115      1  26de80e3bbbe1f053da4131ca7a405644b7443356ec97d...
# 116     37  26de80e3bbbe1f053da4131ca7a405644b7443356ec97d...
# 117      9  26de80e3bbbe1f053da4131ca7a405644b7443356ec97d...
# 118     31  26de80e3bbbe1f053da4131ca7a405644b7443356ec97d...
# 119     98  26de80e3bbbe1f053da4131ca7a405644b7443356ec97d...
# 120     98  26de80e3bbbe1f053da4131ca7a405644b7443356ec97d...
# 121     34  26de80e3bbbe1f053da4131ca7a405644b7443356ec97d...
# 122      8  26de80e3bbbe1f053da4131ca7a405644b7443356ec97d...
# 123     25  26de80e3bbbe1f053da4131ca7a405644b7443356ec97d...
# 124     82  26de80e3bbbe1f053da4131ca7a405644b7443356ec97d...
# 125     82  26de80e3bbbe1f053da4131ca7a405644b7443356ec97d...
# 126      1                                          recon.vba
# 127      1                                          recon.vba
# 128      1                                          recon.vba
# 129      1                                          recon.vba
#
#          function_name label        name sensitivity
# 0             zxOInozC   bad       Right  OBFUSCATED
# 1             zxOInozC   bad     StrConv  OBFUSCATED
# 2             zxOInozC   bad         Mid  OBFUSCATED
# 3             zxOInozC   bad     Replace  OBFUSCATED
# 4             zxOInozC   bad  StrReverse  OBFUSCATED
# 5             zxOInozC   bad        Left  OBFUSCATED
# 6        Document_Open   bad       Right  OBFUSCATED
# 7        Document_Open   bad         Log  OBFUSCATED
# 8        Document_Open   bad     StrConv  OBFUSCATED
# 9        Document_Open   bad         Mid  OBFUSCATED
# 10       Document_Open   bad     Replace  OBFUSCATED
# 11       Document_Open   bad         Asc  OBFUSCATED
# 12       Document_Open   bad       Shell     REGULAR
# 13       Document_Open   bad         Chr  OBFUSCATED
# 14       Document_Open   bad  StrReverse  OBFUSCATED
# 15       Document_Open   bad        Left  OBFUSCATED
# 16          JtJlaLkoKk   bad  StrReverse  OBFUSCATED
# 17          JtJlaLkoKk   bad     StrConv  OBFUSCATED
# 18          JtJlaLkoKk   bad     Replace  OBFUSCATED
# 19            zxOInozC   bad       Right  OBFUSCATED
# 20            zxOInozC   bad     StrConv  OBFUSCATED
# 21            zxOInozC   bad         Mid  OBFUSCATED
# 22            zxOInozC   bad     Replace  OBFUSCATED
# 23            zxOInozC   bad  StrReverse  OBFUSCATED
# 24            zxOInozC   bad        Left  OBFUSCATED
# 25       Document_Open   bad       Right  OBFUSCATED
# 26       Document_Open   bad         Log  OBFUSCATED
# 27       Document_Open   bad     StrConv  OBFUSCATED
# 28       Document_Open   bad         Mid  OBFUSCATED
# 29       Document_Open   bad     Replace  OBFUSCATED
# ..                 ...   ...         ...         ...
# 100         pAKEfogafk   bad  StrReverse  OBFUSCATED
# 101         pAKEfogafk   bad     StrConv  OBFUSCATED
# 102         pAKEfogafk   bad     Replace  OBFUSCATED
# 103           srvpwqPI   bad        CStr  OBFUSCATED
# 104           srvpwqPI   bad         Sqr  OBFUSCATED
# 105           srvpwqPI   bad         Chr  OBFUSCATED
# 106           srvpwqPI   bad       Right  OBFUSCATED
# 107           srvpwqPI   bad        Left  OBFUSCATED
# 108        AiCikVparLS   bad       Right  OBFUSCATED
# 109        AiCikVparLS   bad        http     REGULAR
# 110        AiCikVparLS   bad         Sqr  OBFUSCATED
# 111        AiCikVparLS   bad         Chr  OBFUSCATED
# 112        AiCikVparLS   bad        CStr  OBFUSCATED
# 113        AiCikVparLS   bad        Left  OBFUSCATED
# 114          EwXZcPYLr   bad         Chr  OBFUSCATED
# 115          EwXZcPYLr   bad       Shell     REGULAR
# 116              lQwsM   bad        CStr  OBFUSCATED
# 117              lQwsM   bad         Sqr  OBFUSCATED
# 118              lQwsM   bad         Chr  OBFUSCATED
# 119              lQwsM   bad       Right  OBFUSCATED
# 120              lQwsM   bad        Left  OBFUSCATED
# 121          BZVKUGFUZ   bad        CStr  OBFUSCATED
# 122          BZVKUGFUZ   bad         Sqr  OBFUSCATED
# 123          BZVKUGFUZ   bad         Chr  OBFUSCATED
# 124          BZVKUGFUZ   bad       Right  OBFUSCATED
# 125          BZVKUGFUZ   bad        Left  OBFUSCATED
# 126         VQToEeQETD   bad   GetObject     REGULAR
# 127         VQToEeQETD   bad   ExecQuery     REGULAR
# 128  dRrjWSLJlzRaCZwOQ   bad   GetObject     REGULAR
# 129  dRrjWSLJlzRaCZwOQ   bad   ExecQuery     REGULAR
#
# [130 rows x 6 columns]

# %%
for node in dg.nodes(data=True):
    print(node)
# Out:
# ('Document_Open', {'keywords': "<font color='black'>Shell[1]</font>,<font color='#666699'>Chr[8]</font>,<font color='#666699'>StrReverse[251]</font>,<font color='#666699'>Replace[307]</font>", 'color': 'red', 'calls': [{'count': 1, 'sensitivity': 'REGULAR', 'name': 'Shell'}, {'count': 8, 'sensitivity': 'OBFUSCATED', 'name': 'Chr'}, {'count': 251, 'sensitivity': 'OBFUSCATED', 'name': 'StrReverse'}, {'count': 307, 'sensitivity': 'OBFUSCATED', 'name': 'Replace'}]})
# ('pAKEfogafk', {'keywords': "<font color='#666699'>StrReverse[114]</font>,<font color='#666699'>StrConv[2]</font>,<font color='#666699'>Replace[114]</font>", 'calls': [{'count': 114, 'sensitivity': 'OBFUSCATED', 'name': 'StrReverse'}, {'count': 2, 'sensitivity': 'OBFUSCATED', 'name': 'StrConv'}, {'count': 114, 'sensitivity': 'OBFUSCATED', 'name': 'Replace'}]})

# %%
print node[0]
print node[1]['calls'][0]
# Out:
# pAKEfogafk
# {'count': 114, 'sensitivity': 'OBFUSCATED', 'name': 'StrReverse'}

# %%
import pandas as pd

# %%
data = []
for node in dg.nodes(data=True):
    calls = node[1]['calls']
    for c in calls:
        d = c
        d["function_name"] = node[0]
        data.append(d)
data
# Out:
# [{'count': 1,
#   'function_name': 'Document_Open',
#   'name': 'Shell',
#   'sensitivity': 'REGULAR'},
#  {'count': 8,
#   'function_name': 'Document_Open',
#   'name': 'Chr',
#   'sensitivity': 'OBFUSCATED'},
#  {'count': 251,
#   'function_name': 'Document_Open',
#   'name': 'StrReverse',
#   'sensitivity': 'OBFUSCATED'},
#  {'count': 307,
#   'function_name': 'Document_Open',
#   'name': 'Replace',
#   'sensitivity': 'OBFUSCATED'},
#  {'count': 114,
#   'function_name': 'pAKEfogafk',
#   'name': 'StrReverse',
#   'sensitivity': 'OBFUSCATED'},
#  {'count': 2,
#   'function_name': 'pAKEfogafk',
#   'name': 'StrConv',
#   'sensitivity': 'OBFUSCATED'},
#  {'count': 114,
#   'function_name': 'pAKEfogafk',
#   'name': 'Replace',
#   'sensitivity': 'OBFUSCATED'}]

# %%
import pandas as pd

# %%
pd.DataFrame(data)
# Out:
#    count  function_name        name sensitivity
# 0      1  Document_Open       Shell     REGULAR
# 1      8  Document_Open         Chr  OBFUSCATED
# 2    251  Document_Open  StrReverse  OBFUSCATED
# 3    307  Document_Open     Replace  OBFUSCATED
# 4    114     pAKEfogafk  StrReverse  OBFUSCATED
# 5      2     pAKEfogafk     StrConv  OBFUSCATED
# 6    114     pAKEfogafk     Replace  OBFUSCATED

# %%
for
